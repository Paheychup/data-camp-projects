# %% [markdown]
# ## 1. The most Nobel of Prizes
# <p><img style="float: right;margin:5px 20px 5px 1px; max-width:250px" src="https://assets.datacamp.com/production/project_309/img/Nobel_Prize.png"></p>
# <p>The Nobel Prize is perhaps the worlds most well known scientific award. Except for the honor, prestige and substantial prize money the recipient also gets a gold medal showing Alfred Nobel (1833 - 1896) who established the prize. Every year it's given to scientists and scholars in the categories chemistry, literature, physics, physiology or medicine, economics, and peace. The first Nobel Prize was handed out in 1901, and at that time the Prize was very Eurocentric and male-focused, but nowadays it's not biased in any way whatsoever. Surely. Right?</p>
# <p>Well, we're going to find out! The Nobel Foundation has made a dataset available of all prize winners from the start of the prize, in 1901, to 2016. Let's load it in and take a look.</p>

# %%
# Loading in required libraries
# .... YOUR CODE FOR TASK 1 ....
library(tidyverse)
# Reading in the Nobel Prize data
nobel <- read_csv("datasets/nobel.csv")

# Taking a look at the first couple of winners
head(nobel)
# Out:
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# <U+221A> ggplot2 3.0.0     <U+221A> purrr   0.2.5
# <U+221A> tibble  1.4.2     <U+221A> dplyr   0.7.6
# <U+221A> tidyr   0.8.1     <U+221A> stringr 1.3.1
# <U+221A> readr   1.1.1     <U+221A> forcats 0.3.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
# Parsed with column specification:
# cols(
#   year = col_integer(),
#   category = col_character(),
#   prize = col_character(),
#   motivation = col_character(),
#   prize_share = col_character(),
#   laureate_id = col_integer(),
#   laureate_type = col_character(),
#   full_name = col_character(),
#   birth_date = col_date(format = ""),
#   birth_city = col_character(),
#   birth_country = col_character(),
#   sex = col_character(),
#   organization_name = col_character(),
#   organization_city = col_character(),
#   organization_country = col_character(),
#   death_date = col_date(format = ""),
#   death_city = col_character(),
#   death_country = col_character()
# )
#   year category   prize
# 1 1901 Chemistry  The Nobel Prize in Chemistry 1901
# 2 1901 Literature The Nobel Prize in Literature 1901
# 3 1901 Medicine   The Nobel Prize in Physiology or Medicine 1901
# 4 1901 Peace      The Nobel Peace Prize 1901
# 5 1901 Peace      The Nobel Peace Prize 1901
# 6 1901 Physics    The Nobel Prize in Physics 1901
#   motivation
# 1 "in recognition of the extraordinary services he has rendered by the discovery of the laws of chemical dynamics and osmotic pressure in solutions"
# 2 "in special recognition of his poetic composition, which gives evidence of lofty idealism, artistic perfection and a rare combination of the qualities of both heart and intellect"
# 3 "for his work on serum therapy, especially its application against diphtheria, by which he has opened a new road in the domain of medical science and thereby placed in the hands of the physician a victorious weapon against illness and deaths"
# 4 NA
# 5 NA
# 6 "in recognition of the extraordinary services he has rendered by the discovery of the remarkable rays subsequently named after him"
#   prize_share laureate_id laureate_type full_name
# 1 1/1         160         Individual    Jacobus Henricus van 't Hoff
# 2 1/1         569         Individual    Sully Prudhomme
# 3 1/1         293         Individual    Emil Adolf von Behring
# 4 1/2         462         Individual    Jean Henry Dunant
# 5 1/2         463         Individual    Fr<U+00E9>d<U+00E9>ric Passy
# 6 1/1           1         Individual    Wilhelm Conrad R<U+00F6>ntgen
#   birth_date birth_city         birth_country     sex  organization_name
# 1 1852-08-30 Rotterdam          Netherlands       Male Berlin University
# 2 1839-03-16 Paris              France            Male NA
# 3 1854-03-15 Hansdorf (Lawice)  Prussia (Poland)  Male Marburg University
# 4 1828-05-08 Geneva             Switzerland       Male NA
# 5 1822-05-20 Paris              France            Male NA
# 6 1845-03-27 Lennep (Remscheid) Prussia (Germany) Male Munich University
#   organization_city organization_country death_date death_city
# 1 Berlin            Germany              1911-03-01 Berlin
# 2 NA                NA                   1907-09-07 Ch<U+00E2>tenay
# 3 Marburg           Germany              1917-03-31 Marburg
# 4 NA                NA                   1910-10-30 Heiden
# 5 NA                NA                   1912-06-12 Paris
# 6 Munich            Germany              1923-02-10 Munich
#   death_country
# 1 Germany
# 2 France
# 3 Germany
# 4 Switzerland
# 5 France
# 6 Germany

# %% [markdown]
# ## 2. So, who gets the Nobel Prize?
# <p>Just looking at the first couple of prize winners, or Nobel laureates as they are also called, we already see a celebrity: Wilhelm Conrad Röntgen, the guy who discovered X-rays. And actually, we see that all of the winners in 1901 were guys that came from Europe. But that was back in 1901, looking at all winners in the dataset, from 1901 to 2016, which sex and which country is the most commonly represented? </p>
# <p>(For <em>country</em>, we will use the <code>birth_country</code> of the winner, as the <code>organization_country</code> is <code>NA</code> for all shared Nobel Prizes.)</p>

# %%
#unique(nobel$prize)

# Counting the number of (possibly shared) Nobel Prizes handed
# out between 1901 and 2016
nobel %>% count(prize)

# Counting the number of prizes won by male and female recipients.
nobel %>%
    count(sex)

# Counting the number of prizes won by different nationalities.
nobel %>%
    count(birth_country) %>% arrange(n) %>% slice(1:20)

nobel %>% group_by(birth_country) %>% count() 

nobel %>% group_by(birth_country) %>% count() %>% 
filter(n>10)%>%
ggplot(aes(x=reorder(birth_country,-n),y=n,fill=birth_country))+
geom_bar(stat="identity")+theme(text = element_text(size=8),
        axis.text.x = element_text(angle=90, hjust=1))+
        scale_y_log10()

nobel %>% group_by(birth_country) %>% count() %>% 
filter(n>10)%>%
ggplot(aes(x=birth_country,y=n,fill=birth_country))+
geom_bar(position="fill")+theme(text = element_text(size=8),
        axis.text.x = element_text(angle=90, hjust=1))+
        scale_y_log10()
# Out:
#     prize                                                 n
# 1   The Nobel Peace Prize 1901                            2
# 2   The Nobel Peace Prize 1902                            2
# 3   The Nobel Peace Prize 1903                            1
# 4   The Nobel Peace Prize 1904                            1
# 5   The Nobel Peace Prize 1905                            1
# 6   The Nobel Peace Prize 1906                            1
# 7   The Nobel Peace Prize 1907                            2
# 8   The Nobel Peace Prize 1908                            2
# 9   The Nobel Peace Prize 1909                            2
# 10  The Nobel Peace Prize 1910                            1
# 11  The Nobel Peace Prize 1911                            2
# 12  The Nobel Peace Prize 1912                            1
# 13  The Nobel Peace Prize 1913                            1
# 14  The Nobel Peace Prize 1917                            1
# 15  The Nobel Peace Prize 1919                            1
# 16  The Nobel Peace Prize 1920                            1
# 17  The Nobel Peace Prize 1921                            2
# 18  The Nobel Peace Prize 1922                            1
# 19  The Nobel Peace Prize 1925                            2
# 20  The Nobel Peace Prize 1926                            2
# 21  The Nobel Peace Prize 1927                            2
# 22  The Nobel Peace Prize 1929                            1
# 23  The Nobel Peace Prize 1930                            1
# 24  The Nobel Peace Prize 1931                            2
# 25  The Nobel Peace Prize 1933                            1
# 26  The Nobel Peace Prize 1934                            1
# 27  The Nobel Peace Prize 1935                            1
# 28  The Nobel Peace Prize 1936                            1
# 29  The Nobel Peace Prize 1937                            1
# 30  The Nobel Peace Prize 1938                            1
# ... ...                                                   ...
# 550 The Sveriges Riksbank Prize in Economic Sciences 1987 1
# 551 The Sveriges Riksbank Prize in Economic Sciences 1988 1
# 552 The Sveriges Riksbank Prize in Economic Sciences 1989 1
# 553 The Sveriges Riksbank Prize in Economic Sciences 1990 3
# 554 The Sveriges Riksbank Prize in Economic Sciences 1991 1
# 555 The Sveriges Riksbank Prize in Economic Sciences 1992 1
# 556 The Sveriges Riksbank Prize in Economic Sciences 1993 2
# 557 The Sveriges Riksbank Prize in Economic Sciences 1994 3
# 558 The Sveriges Riksbank Prize in Economic Sciences 1995 1
# 559 The Sveriges Riksbank Prize in Economic Sciences 1996 2
# 560 The Sveriges Riksbank Prize in Economic Sciences 1997 2
# 561 The Sveriges Riksbank Prize in Economic Sciences 1998 1
# 562 The Sveriges Riksbank Prize in Economic Sciences 1999 1
# 563 The Sveriges Riksbank Prize in Economic Sciences 2000 2
# 564 The Sveriges Riksbank Prize in Economic Sciences 2001 3
# 565 The Sveriges Riksbank Prize in Economic Sciences 2002 2
# 566 The Sveriges Riksbank Prize in Economic Sciences 2003 2
# 567 The Sveriges Riksbank Prize in Economic Sciences 2004 2
# 568 The Sveriges Riksbank Prize in Economic Sciences 2005 2
# 569 The Sveriges Riksbank Prize in Economic Sciences 2006 1
# 570 The Sveriges Riksbank Prize in Economic Sciences 2007 3
# 571 The Sveriges Riksbank Prize in Economic Sciences 2008 1
# 572 The Sveriges Riksbank Prize in Economic Sciences 2009 2
# 573 The Sveriges Riksbank Prize in Economic Sciences 2010 3
# 574 The Sveriges Riksbank Prize in Economic Sciences 2011 2
# 575 The Sveriges Riksbank Prize in Economic Sciences 2012 2
# 576 The Sveriges Riksbank Prize in Economic Sciences 2013 3
# 577 The Sveriges Riksbank Prize in Economic Sciences 2014 1
# 578 The Sveriges Riksbank Prize in Economic Sciences 2015 1
# 579 The Sveriges Riksbank Prize in Economic Sciences 2016 2
#   sex    n
# 1 Female  49
# 2 Male   836
# 3 NA      26
#    birth_country                              n
# 1  Austria-Hungary (Austria)                  1
# 2  Austria-Hungary (Bosnia and Herzegovina)   1
# 3  Austria-Hungary (Croatia)                  1
# 4  Austria-Hungary (Poland)                   1
# 5  Austria-Hungary (Slovenia)                 1
# 6  Austria-Hungary (Ukraine)                  1
# 7  Austrian Empire (Czech Republic)           1
# 8  Austrian Empire (Italy)                    1
# 9  Bavaria (Germany)                          1
# 10 Bosnia (Bosnia and Herzegovina)            1
# 11 Brazil                                     1
# 12 British India (Bangladesh)                 1
# 13 British India (India)                      1
# 14 British Protectorate of Palestine (Israel) 1
# 15 British West Indies (Saint Lucia)          1
# 16 Bulgaria                                   1
# 17 Burma (Myanmar)                            1
# 18 Costa Rica                                 1
# 19 Crete (Greece)                             1
# 20 Cyprus                                     1
#     birth_country                                 n
# 1   Argentina                                      4
# 2   Australia                                     10
# 3   Austria                                       14
# 4   Austria-Hungary (Austria)                      1
# 5   Austria-Hungary (Bosnia and Herzegovina)       1
# 6   Austria-Hungary (Croatia)                      1
# 7   Austria-Hungary (Czech Republic)               4
# 8   Austria-Hungary (Hungary)                      3
# 9   Austria-Hungary (Poland)                       1
# 10  Austria-Hungary (Slovenia)                     1
# 11  Austria-Hungary (Ukraine)                      1
# 12  Austrian Empire (Austria)                      2
# 13  Austrian Empire (Czech Republic)               1
# 14  Austrian Empire (Italy)                        1
# 15  Bavaria (Germany)                              1
# 16  Belgium                                        9
# 17  Bosnia (Bosnia and Herzegovina)                1
# 18  Brazil                                         1
# 19  British India (Bangladesh)                     1
# 20  British India (India)                          1
# 21  British Mandate of Palestine (Israel)          5
# 22  British Protectorate of Palestine (Israel)     1
# 23  British West Indies (Saint Lucia)              1
# 24  Bulgaria                                       1
# 25  Burma (Myanmar)                                1
# 26  Canada                                        18
# 27  Chile                                          2
# 28  China                                         11
# 29  Colombia                                       2
# 30  Costa Rica                                     1
# ... ...                                           ...
# 93  Russian Empire (Finland)                        3
# 94  Russian Empire (Latvia)                         1
# 95  Russian Empire (Lithuania)                      1
# 96  Russian Empire (Poland)                         5
# 97  Russian Empire (Russia)                         2
# 98  Russian Empire (Ukraine)                        2
# 99  Saint Lucia                                     1
# 100 Schleswig (Germany)                             2
# 101 Scotland                                        9
# 102 South Africa                                    9
# 103 Southern Rhodesia (Zimbabwe)                    1
# 104 Spain                                           7
# 105 Sweden                                         29
# 106 Switzerland                                    16
# 107 Taiwan                                          1
# 108 Tibet (People's Republic of China)              1
# 109 Trinidad                                        1
# 110 Turkey                                          2
# 111 Tuscany (Italy)                                 1
# 112 Ukraine                                         1
# 113 Union of Soviet Socialist Republics (Belarus)   1
# 114 Union of Soviet Socialist Republics (Russia)    4
# 115 United Kingdom                                 85
# 116 United States of America                      259
# 117 Venezuela                                       1
# 118 Vietnam                                         1
# 119 W&uuml;rttemberg (Germany)                      1
# 120 West Germany (Germany)                          5
# 121 Yemen                                           1
# 122 NA                                             26
# ERROR while rich displaying an object: Error: stat_count() must not be used with a y aesthetic.
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. mime2repr[[mime]](obj)
# 8. repr_text.default(obj)
# 9. paste(capture.output(print(obj)), collapse = "\n")
# 10. capture.output(print(obj))
# 11. evalVis(expr)
# 12. withVisible(eval(expr, pf))
# 13. eval(expr, pf)
# 14. eval(expr, pf)
# 15. print(obj)
# 16. print.ggplot(obj)
# 17. ggplot_build(x)
# 18. ggplot_build.ggplot(x)
# 19. by_layer(function(l, d) l$compute_statistic(d, layout))
# 20. f(l = layers[[i]], d = data[[i]])
# 21. l$compute_statistic(d, layout)
# 22. f(..., self = self)
# 23. self$stat$setup_params(data, self$stat_params)
# 24. f(...)
# 25. stop("stat_count() must not be used with a y aesthetic.", call. = FALSE)
# plot without title
# plot without title

# %% [markdown]
# ## 3. USA dominance
# <p>Not so surprising perhaps: the most common Nobel laureate between 1901 and 2016 was a man born in the United States of America. But in 1901 all the laureates were European. When did the USA start to dominate the Nobel Prize charts?</p>

# %%
# Calculating the proportion of USA born winners per decade
prop_usa_winners <- nobel %>% 
    mutate(usa_born_winner=if_else(birth_country=="United States of America",1,0)) %>%
    mutate(decade=floor(year/10)*10) %>%
    group_by(decade) %>% 
    summarize(proportion=mean(usa_born_winner,na.rm=TRUE))

# Display the proportions of USA born winners per decade
# .... YOUR CODE FOR TASK 3 ....
prop_usa_winners
# Out:
#    decade proportion
# 1  1900   0.01785714
# 2  1910   0.07894737
# 3  1920   0.07407407
# 4  1930   0.25454545
# 5  1940   0.32500000
# 6  1950   0.29577465
# 7  1960   0.28000000
# 8  1970   0.32038835
# 9  1980   0.32978723
# 10 1990   0.41584158
# 11 2000   0.43697479
# 12 2010   0.30379747

# %% [markdown]
# ## 4. USA dominance, visualized
# <p>A table is OK, but to <em>see</em> when the USA started to dominate the Nobel charts we need a plot!</p>

# %%
# Setting the size of plots in this notebook
options(repr.plot.width=7, repr.plot.height=4)

# Plotting USA born winners
# .... YOUR CODE FOR TASK 4 ....
ggplot(prop_usa_winners,aes(x=decade,y=proportion))+ geom_point()+geom_line()
# Out:
# plot without title

# %% [markdown]
# ## 5. What is the gender of a typical Nobel Prize winner?
# <p>So the USA became the dominating winner of the Nobel Prize first in the 1930s and has kept the leading position ever since. But one group that was in the lead from the start, and never seems to let go, are <em>men</em>. Maybe it shouldn't come as a shock that there is some imbalance between how many male and female prize winners there are, but how significant is this imbalance? And is it better or worse within specific prize categories like physics, medicine, literature, etc.?</p>

# %%
# Calculating the proportion of female laureates per decade
prop_female_winners <- nobel %>%
    mutate(female_winner=if_else(sex=="Female",TRUE,FALSE)) %>%
    mutate(decade=floor(year/10)*10) %>% group_by(decade,category) %>% summarize(proportion=mean(female_winner,na.rm=T))



prop_female_winners
# Plotting the proportion of female laureates per decade
# .... YOUR CODE FOR TASK 5 ....
ggplot(prop_female_winners,aes(decade,proportion,color=category))+ geom_line()+geom_point()
# Out:
#     decade category   proportion
# 1   1900   Chemistry  0.00000000
# 2   1900   Literature 0.10000000
# 3   1900   Medicine   0.00000000
# 4   1900   Peace      0.07692308
# 5   1900   Physics    0.07692308
# 6   1910   Chemistry  0.12500000
# 7   1910   Literature 0.00000000
# 8   1910   Medicine   0.00000000
# 9   1910   Peace      0.00000000
# 10  1910   Physics    0.00000000
# 11  1920   Chemistry  0.00000000
# 12  1920   Literature 0.20000000
# 13  1920   Medicine   0.00000000
# 14  1920   Peace      0.00000000
# 15  1920   Physics    0.00000000
# 16  1930   Chemistry  0.07692308
# 17  1930   Literature 0.11111111
# 18  1930   Medicine   0.00000000
# 19  1930   Peace      0.12500000
# 20  1930   Physics    0.00000000
# 21  1940   Chemistry  0.00000000
# 22  1940   Literature 0.16666667
# 23  1940   Medicine   0.07142857
# 24  1940   Peace      0.25000000
# 25  1940   Physics    0.00000000
# 26  1950   Chemistry  0.00000000
# 27  1950   Literature 0.00000000
# 28  1950   Medicine   0.00000000
# 29  1950   Peace      0.00000000
# 30  1950   Physics    0.00000000
# ... ...    ...        ...
# 37  1970   Chemistry  0.0000000
# 38  1970   Economics  0.0000000
# 39  1970   Literature 0.0000000
# 40  1970   Medicine   0.0400000
# 41  1970   Peace      0.2500000
# 42  1970   Physics    0.0000000
# 43  1980   Chemistry  0.0000000
# 44  1980   Economics  0.0000000
# 45  1980   Literature 0.0000000
# 46  1980   Medicine   0.1304348
# 47  1980   Peace      0.1250000
# 48  1980   Physics    0.0000000
# 49  1990   Chemistry  0.0000000
# 50  1990   Economics  0.0000000
# 51  1990   Literature 0.3000000
# 52  1990   Medicine   0.0500000
# 53  1990   Peace      0.2142857
# 54  1990   Physics    0.0000000
# 55  2000   Chemistry  0.0400000
# 56  2000   Economics  0.0500000
# 57  2000   Literature 0.3000000
# 58  2000   Medicine   0.1538462
# 59  2000   Peace      0.2000000
# 60  2000   Physics    0.0000000
# 61  2010   Chemistry  0.0000000
# 62  2010   Economics  0.0000000
# 63  2010   Literature 0.2857143
# 64  2010   Medicine   0.1250000
# 65  2010   Peace      0.5714286
# 66  2010   Physics    0.0000000
# plot without title

# %% [markdown]
# ## 6. The first woman to win the Nobel Prize
# <p>The plot above is a bit messy as the lines are overplotting. But it does show some interesting trends and patterns. Overall the imbalance is pretty large with physics, economics, and chemistry having the largest imbalance. Medicine has a somewhat positive trend, and since the 1990s the literature prize is also now more balanced. The big outlier is the peace prize during the 2010s, but keep in mind that this just covers the years 2010 to 2016.</p>
# <p>Given this imbalance, who was the first woman to receive a Nobel Prize? And in what category?</p>

# %%
# Picking out the first woman to win a Nobel Prize
nobel %>%
    filter(sex=="Female") %>% top_n(1,desc(year))
# Out:
#   year category prize
# 1 1903 Physics  The Nobel Prize in Physics 1903
#   motivation
# 1 "in recognition of the extraordinary services they have rendered by their joint researches on the radiation phenomena discovered by Professor Henri Becquerel"
#   prize_share laureate_id laureate_type full_name
# 1 1/4         6           Individual    Marie Curie, n<U+00E9>e Sklodowska
#   birth_date birth_city birth_country           sex    organization_name
# 1 1867-11-07 Warsaw     Russian Empire (Poland) Female NA
#   organization_city organization_country death_date death_city death_country
# 1 NA                NA                   1934-07-04 Sallanches France

# %% [markdown]
# ## 7. Repeat laureates
# <p>For most scientists/writers/activists a Nobel Prize would be the crowning achievement of a long career. But for some people, one is just not enough, and there are few that have gotten it more than once. Who are these lucky few? (Having won no Nobel Prize myself, I'll assume it's just about luck.)</p>

# %%
# Selecting the laureates that have received 2 or more prizes.
nobel %>%
    count(full_name) %>% filter(n!=1)
# Out:
#   full_name
# 1 Comit<U+00E9> international de la Croix Rouge (International Committee of the Red Cross)
# 2 Frederick Sanger
# 3 John Bardeen
# 4 Linus Carl Pauling
# 5 Marie Curie, n<U+00E9>e Sklodowska
# 6 Office of the United Nations High Commissioner for Refugees (UNHCR)
#   n
# 1 3
# 2 2
# 3 2
# 4 2
# 5 2
# 6 2

# %% [markdown]
# ## 8. How old are you when you get the prize?
# <p>The list of repeat winners contains some illustrious names! We again meet Marie Curie, who got the prize in physics for discovering radiation and in chemistry for isolating radium and polonium. John Bardeen got it twice in physics for transistors and superconductivity, Frederick Sanger got it twice in chemistry, and Linus Carl Pauling got it first in chemistry and later in peace for his work in promoting nuclear disarmament. We also learn that organizations also get the prize as both the Red Cross and the UNHCR have gotten it twice.</p>
# <p>But how old are you generally when you get the prize?</p>

# %%
# Loading the lubridate package
# .... YOUR CODE FOR TASK 8 ....
library(lubridate)
# Calculating the age of Nobel Prize winners
nobel_age <- nobel %>%
    mutate(age=year-year(birth_date))

# Plotting the age of Nobel Prize winners
# .... YOUR CODE FOR TASK 8 ....
ggplot(nobel_age,aes(x=year,y=age))+geom_point()+geom_smooth(method="lm")
# Out:
# Attaching package: 'lubridate'
#
# The following object is masked from 'package:base':
#
#     date
#
# Warning message:
# "Removed 28 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 28 rows containing missing values (geom_point)."
# plot without title

# %% [markdown]
# ## 9. Age differences between prize categories
# <p>The plot above shows us a lot! We see that people use to be around 55 when they received the price, but nowadays the average is closer to 65. But there is a large spread in the laureates' ages, and while most are 50+, some are very young.</p>
# <p>We also see that the density of points is much high nowadays than in the early 1900s -- nowadays many more of the prizes are shared, and so there are many more winners. We also see that there was a disruption in awarded prizes around the Second World War (1939 - 1945). </p>
# <p>Let's look at age trends within different prize categories.</p>

# %%
# Same plot as above, but faceted by the category of the Nobel Prize
# .... YOUR CODE FOR TASK 9 ....
ggplot(nobel_age,aes(x=year,y=age))+geom_point()+geom_smooth(method="lm")+facet_wrap(~category)
# Out:
# Warning message:
# "Removed 28 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 28 rows containing missing values (geom_point)."
# plot without title

# %% [markdown]
# ## 10. Oldest and youngest winners
# <p>Another plot with lots of exciting stuff going on! We see that both winners of the chemistry, medicine, and physics prize have gotten older over time. The trend is strongest for physics: the average age used to be below 50, and now it's almost 70. Literature and economics are more stable, and we also see that economics is a newer category. But peace shows an opposite trend where winners are getting younger! </p>
# <p>In the peace category we also a winner around 2010 that seems exceptionally young. This begs the questions, who are the oldest and youngest people ever to have won a Nobel Prize?</p>

# %%
# The oldest winner of a Nobel Prize as of 2016
nobel_age %>% top_n(1,desc(birth_date))

# The youngest winner of a Nobel Prize as of 2016
nobel_age %>% top_n(1,birth_date)
# Out:
#   year category   prize
# 1 1902 Literature The Nobel Prize in Literature 1902
#   motivation
# 1 "the greatest living master of the art of historical writing, with special reference to his monumental work, <I>A history of Rome</I>"
#   prize_share laureate_id laureate_type full_name
# 1 1/1         571         Individual    Christian Matthias Theodor Mommsen
#   birth_date birth_city birth_country       sex  organization_name
# 1 1817-11-30 Garding    Schleswig (Germany) Male NA
#   organization_city organization_country death_date death_city
# 1 NA                NA                   1903-11-01 Charlottenburg
#   death_country age
# 1 Germany       85
#   year category prize
# 1 2014 Peace    The Nobel Peace Prize 2014
#   motivation
# 1 "for their struggle against the suppression of children and young people and for the right of all children to education"
#   prize_share laureate_id laureate_type full_name        birth_date birth_city
# 1 1/2         914         Individual    Malala Yousafzai 1997-07-12 Mingora
#   birth_country sex    organization_name organization_city organization_country
# 1 Pakistan      Female NA                NA                NA
#   death_date death_city death_country age
# 1 <NA>       NA         NA            17

# %% [markdown]
# ## 11. You get a prize!
# <p><img style="float: right;margin:20px 20px 20px 20px; max-width:200px" src="https://assets.datacamp.com/production/project_309/img/paint_nobel_prize.png"></p>
# <p>Hey! You get a prize for making it to the very end of this notebook! It might not be a Nobel Prize, but I made it myself in paint so it should count for something. But don't despair, Leonid Hurwicz was 90 years old when he got his prize, so it might not be too late for you. Who knows.</p>
# <p>Before you leave, what was again the name of the youngest winner ever who in 2014 got the prize for "[her] struggle against the suppression of children and young people and for the right of all children to education"?</p>

# %%
# The name of the youngest winner of the Nobel Prize as of 2016
youngest_winner <- "Malala Yousafzai"
